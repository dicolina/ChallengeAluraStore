# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd
import matplotlib.pyplot as plt

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
tienda['Total'] = tienda['Precio'] + tienda['Costo de envío']
facturacion_total1 = tienda['Total'].sum()

print(f"Facturación Total de al tienda 1: ${facturacion_total1:.2f}")
# Out:
# Facturación Total de al tienda 1: $1212258300.00

# %%
tienda2['Total'] = tienda2['Precio'] + tienda2['Costo de envío']
facturacion_total2 = tienda2['Total'].sum()

print(f"Facturación Total de la tienda 2: ${facturacion_total2:.2f}")
# Out:
# Facturación Total de la tienda 2: $1175828600.00

# %%
tienda3['Total'] = tienda3['Precio'] + tienda3['Costo de envío']
facturacion_total3 = tienda3['Total'].sum()

print(f"Facturación Total de la tienda 3: ${facturacion_total3:.2f}")
# Out:
# Facturación Total de la tienda 3: $1156536200.00

# %%
tienda4['Total'] = tienda4['Precio'] + tienda4['Costo de envío']
facturacion_total4 = tienda4['Total'].sum()

print(f"Facturación Total de la tienda 4: ${facturacion_total4:.2f}")
# Out:
# Facturación Total de la tienda 4: $1093693100.00

# %%
facturaciones = [facturacion_total1, facturacion_total2, facturacion_total3, facturacion_total4]
facturaciones
# Out:
# [np.float64(1212258300.0),
#  np.float64(1175828600.0),
#  np.float64(1156536200.0),
#  np.float64(1093693100.0)]

# %%
categorias = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
ventas = [facturacion_total1, facturacion_total2, facturacion_total3, facturacion_total4]
colores = ['blue', 'green', 'red', 'purple']

# Crear figura y ejes
fig, ax = plt.subplots(figsize=(8, 5))

# Crear barras
barras = ax.bar(categorias, ventas, color=colores)

# Añadir título y etiquetas
ax.set_title('Facturacion por tienda', fontsize=14)
ax.set_xlabel('Tiendas', fontsize=12)
ax.set_ylabel('Facturacion', fontsize=12)

# Añadir valores encima de las barras
for barra in barras:
    height = barra.get_height()
    ax.text(barra.get_x() + barra.get_width()/2., height,
            f'{height}',
            ha='center', va='bottom')

# Mostrar gráfico
plt.tight_layout()
plt.show()

# %% [markdown]
# # 2. Ventas por categoría

# %% [markdown]
# Analisis de Ventas por categoria de la Tienda numero 1

# %%
# Agrupar por categoría y calcular el total de ingresos
ventas_por_categoria = tienda.groupby('Categoría del Producto')['Total'].sum().sort_values(ascending=False)

print("Ventas por Categoría:")
print(ventas_por_categoria)

# Gráfico de Torta para Ventas por Categoría
plt.figure(figsize=(10, 8))
plt.pie(ventas_por_categoria, labels=ventas_por_categoria.index, autopct='%1.1f%%', startangle=90)
plt.title('Ventas por Categoría')
plt.show()
# Out:
# Ventas por Categoría:
# Categoría del Producto
# Electrónicos               452457200.0
# Electrodomésticos          383009200.0
# Muebles                    197628600.0
# Instrumentos musicales      96182900.0
# Deportes y diversión        41411100.0
# Juguetes                    18975200.0
# Artículos para el hogar     13342200.0
# Libros                       9251900.0
# Name: Total, dtype: float64

# %% [markdown]
# Analisis de Ventas por categoria de la Tienda numero 2

# %%
# Agrupar por categoría y calcular el total de ingresos
ventas_por_categoria = tienda2.groupby('Categoría del Producto')['Total'].sum().sort_values(ascending=False)

print("Ventas por Categoría:")
print(ventas_por_categoria)

# Gráfico de Torta para Ventas por Categoría
plt.figure(figsize=(10, 8))
plt.pie(ventas_por_categoria, labels=ventas_por_categoria.index, autopct='%1.1f%%', startangle=90)
plt.title('Ventas por Categoría')
plt.show()
# Out:
# Ventas por Categoría:
# Categoría del Producto
# Electrónicos               432645300.0
# Electrodomésticos          367123400.0
# Muebles                    185862400.0
# Instrumentos musicales     110548000.0
# Deportes y diversión        36621800.0
# Juguetes                    16833000.0
# Artículos para el hogar     15547700.0
# Libros                      10647000.0
# Name: Total, dtype: float64

# %% [markdown]
# Analisis de Ventas por categoria de la Tienda numero 3

# %%
# Agrupar por categoría y calcular el total de ingresos
ventas_por_categoria = tienda3.groupby('Categoría del Producto')['Total'].sum().sort_values(ascending=False)

print("Ventas por Categoría:")
print(ventas_por_categoria)

# Gráfico de Torta para Ventas por Categoría
plt.figure(figsize=(10, 8))
plt.pie(ventas_por_categoria, labels=ventas_por_categoria.index, autopct='%1.1f%%', startangle=90)
plt.title('Ventas por Categoría')
plt.show()
# Out:
# Ventas por Categoría:
# Categoría del Producto
# Electrónicos               432631700.0
# Electrodomésticos          346732100.0
# Muebles                    211856200.0
# Instrumentos musicales      81489700.0
# Deportes y diversión        37516200.0
# Juguetes                    20442800.0
# Artículos para el hogar     15872400.0
# Libros                       9995100.0
# Name: Total, dtype: float64

# %% [markdown]
# Analisis de Ventas por categoria de la Tienda numero 4

# %%
# Agrupar por categoría y calcular el total de ingresos
ventas_por_categoria = tienda4.groupby('Categoría del Producto')['Total'].sum().sort_values(ascending=False)

print("Ventas por Categoría:")
print(ventas_por_categoria)

# Gráfico de Torta para Ventas por Categoría
plt.figure(figsize=(10, 8))
plt.pie(ventas_por_categoria, labels=ventas_por_categoria.index, autopct='%1.1f%%', startangle=90)
plt.title('Ventas por Categoría')
plt.show()
# Out:
# Ventas por Categoría:
# Categoría del Producto
# Electrónicos               431304400.0
# Electrodomésticos          298282700.0
# Muebles                    202764200.0
# Instrumentos musicales      79056300.0
# Deportes y diversión        35120200.0
# Juguetes                    21374700.0
# Artículos para el hogar     15928600.0
# Libros                       9862000.0
# Name: Total, dtype: float64

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %% [markdown]
# Calificacion promedio de las tiendas numero 1, 2, 3 y 4

# %%
# Calcular la calificación promedio
calificacion_promedio = tienda['Calificación'].mean()
calificacion_promedio2 = tienda2['Calificación'].mean()
calificacion_promedio3 = tienda3['Calificación'].mean()
calificacion_promedio4 = tienda4['Calificación'].mean()

categorias = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
calificacion_promedio_tiendas = [calificacion_promedio, calificacion_promedio2, calificacion_promedio, calificacion_promedio4]
colores = ['blue', 'green', 'red', 'purple']

print(f"Calificación Promedio por tienda numero 1: {calificacion_promedio:.4f}")
print(f"Calificación Promedio por tienda numero 2: {calificacion_promedio2:.4f}")
print(f"Calificación Promedio por tienda numero 3: {calificacion_promedio3:.4f}")
print(f"Calificación Promedio por tienda numero 4: {calificacion_promedio4:.4f}")
print(" ")

# Crear figura y ejes
fig, ax = plt.subplots(figsize=(8, 5))

# Crear barras
barras = ax.bar(categorias, calificacion_promedio_tiendas, color=colores)

# Añadir título y etiquetas
ax.set_title('Calificacion promedio por tienda', fontsize=14)
ax.set_xlabel('Tiendas', fontsize=12)
ax.set_ylabel('Promedios', fontsize=12)

# Añadir valores encima de las barras
for barra in barras:
    height = barra.get_height()
    ax.text(barra.get_x() + barra.get_width()/2., height,
            f'{height}',
            ha='center', va='bottom')

# Mostrar gráfico
plt.tight_layout()
plt.show()
# Out:
# Calificación Promedio por tienda numero 1: 3.9767
# Calificación Promedio por tienda numero 2: 4.0373
# Calificación Promedio por tienda numero 3: 4.0483
# Calificación Promedio por tienda numero 4: 3.9958

# %% [markdown]
# # 4. Productos más y menos vendidos

# %% [markdown]
# Productos más y menos vendidos de la tienda numero 1

# %%
# Contar la cantidad de veces que aparece cada producto
productos_vendidos = tienda['Producto'].value_counts()

# Productos más vendidos
productos_mas_vendidos = productos_vendidos.head(5)
print("Productos Más Vendidos Tienda 1:")
print(productos_mas_vendidos)

# Productos menos vendidos
productos_menos_vendidos = productos_vendidos.tail(5)
print("Productos Menos Vendidos Tienda 1:")
print(productos_menos_vendidos)

# Gráfico de Barras para Productos Más Vendidos
plt.figure(figsize=(10, 6))
productos_mas_vendidos.plot(kind='bar', color='orange')
plt.title('Productos Más Vendidos Tienda 1')
plt.ylabel('Cantidad Vendida')
plt.show()
print("")

# Gráfico de Barras para Productos Menos Vendidos
plt.figure(figsize=(10, 6))
productos_menos_vendidos.plot(kind='bar', color='red')
plt.title('Productos Menos Vendidos Tienda 1')
plt.ylabel('Cantidad Vendida')
plt.show()
# Out:
# Productos Más Vendidos Tienda 1:
# Producto
# Microondas          60
# TV LED UHD 4K       60
# Armario             60
# Secadora de ropa    58
# Mesa de noche       56
# Name: count, dtype: int64
# Productos Menos Vendidos Tienda 1:
# Producto
# Ciencia de datos con Python    39
# Pandereta                      36
# Olla de presión                35
# Auriculares con micrófono      33
# Celular ABXY                   33
# Name: count, dtype: int64

# %% [markdown]
# Productos más y menos vendidos de la tienda numero 2

# %%
# Contar la cantidad de veces que aparece cada producto
productos_vendidos = tienda2['Producto'].value_counts()

# Productos más vendidos
productos_mas_vendidos = productos_vendidos.head(5)
print("Productos Más Vendidos Tienda 2:")
print(productos_mas_vendidos)

# Productos menos vendidos
productos_menos_vendidos = productos_vendidos.tail(5)
print("Productos Menos Vendidos Tienda 2:")
print(productos_menos_vendidos)

# Gráfico de Barras para Productos Más Vendidos
plt.figure(figsize=(10, 6))
productos_mas_vendidos.plot(kind='bar', color='orange')
plt.title('Productos Más Vendidos Tienda 2')
plt.ylabel('Cantidad Vendida')
plt.show()
print("")

# Gráfico de Barras para Productos Menos Vendidos
plt.figure(figsize=(10, 6))
productos_menos_vendidos.plot(kind='bar', color='red')
plt.title('Productos Menos Vendidos Tienda 2')
plt.ylabel('Cantidad Vendida')
plt.show()
# Out:
# Productos Más Vendidos Tienda 2:
# Producto
# Iniciando en programación    65
# Microondas                   62
# Batería                      61
# Guitarra acústica            58
# Pandereta                    58
# Name: count, dtype: int64
# Productos Menos Vendidos Tienda 2:
# Producto
# Auriculares        37
# Sillón             35
# Mesa de comedor    34
# Impresora          34
# Juego de mesa      32
# Name: count, dtype: int64

# %% [markdown]
# Productos más y menos vendidos de la tienda numero 3

# %%
# Contar la cantidad de veces que aparece cada producto
productos_vendidos = tienda3['Producto'].value_counts()

# Productos más vendidos
productos_mas_vendidos = productos_vendidos.head(5)
print("Productos Más Vendidos Tienda 3:")
print(productos_mas_vendidos)

# Productos menos vendidos
productos_menos_vendidos = productos_vendidos.tail(5)
print("Productos Menos Vendidos Tienda 3:")
print(productos_menos_vendidos)

# Gráfico de Barras para Productos Más Vendidos
plt.figure(figsize=(10, 6))
productos_mas_vendidos.plot(kind='bar', color='orange')
plt.title('Productos Más Vendidos Tienda 3')
plt.ylabel('Cantidad Vendida')
plt.show()
print("")

# Gráfico de Barras para Productos Menos Vendidos
plt.figure(figsize=(10, 6))
productos_menos_vendidos.plot(kind='bar', color='red')
plt.title('Productos Menos Vendidos Tienda 3')
plt.ylabel('Cantidad Vendida')
plt.show()
# Out:
# Productos Más Vendidos Tienda 3:
# Producto
# Kit de bancas      57
# Mesa de comedor    56
# Cama king          56
# Set de ollas       55
# Mesa de noche      55
# Name: count, dtype: int64
# Productos Menos Vendidos Tienda 3:
# Producto
# Guitarra eléctrica         38
# Set de vasos               36
# Mochila                    36
# Microondas                 36
# Bloques de construcción    35
# Name: count, dtype: int64

# %% [markdown]
# Productos más y menos vendidos de la tienda numero 4

# %%
# Contar la cantidad de veces que aparece cada producto
productos_vendidos = tienda4['Producto'].value_counts()

# Productos más vendidos
productos_mas_vendidos = productos_vendidos.head(5)
print("Productos Más Vendidos Tienda 4:")
print(productos_mas_vendidos)

# Productos menos vendidos
productos_menos_vendidos = productos_vendidos.tail(5)
print("Productos Menos Vendidos Tienda 4:")
print(productos_menos_vendidos)

# Gráfico de Barras para Productos Más Vendidos
plt.figure(figsize=(10, 6))
productos_mas_vendidos.plot(kind='bar', color='orange')
plt.title('Productos Más Vendidos Tienda 4')
plt.ylabel('Cantidad Vendida')
plt.show()
print("")

# Gráfico de Barras para Productos Menos Vendidos
plt.figure(figsize=(10, 6))
productos_menos_vendidos.plot(kind='bar', color='red')
plt.title('Productos Menos Vendidos Tienda 4')
plt.ylabel('Cantidad Vendida')
plt.show()
# Out:
# Productos Más Vendidos Tienda 4:
# Producto
# Cama box                     62
# Cubertería                   59
# Dashboards con Power BI      56
# Cama king                    56
# Carrito de control remoto    55
# Name: count, dtype: int64
# Productos Menos Vendidos Tienda 4:
# Producto
# Refrigerador                   38
# Ciencia de datos con Python    38
# Guitarra acústica              37
# Armario                        34
# Guitarra eléctrica             33
# Name: count, dtype: int64

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
# Calcular el envío promedio
envio_promedio = tienda['Costo de envío'].mean()
envio_promedio2 = tienda2['Costo de envío'].mean()
envio_promedio3 = tienda3['Costo de envío'].mean()
envio_promedio4 = tienda4['Costo de envío'].mean()
colores = ['blue', 'green', 'red', 'purple']

print(f"Envío Promedio por tienda numero 1: ${envio_promedio:.2f}")

# Gráfico de Barras para Envío Promedio
plt.figure(figsize=(8, 6))
plt.bar(['Envío Promedio'], [envio_promedio], color='blue')
plt.title('Envío Promedio por Tienda 1')
plt.ylabel('Costo de Envío ($)')
plt.show()

print(" ")
print(f"Envío Promedio por Tienda numero 2: ${envio_promedio2:.2f}")

# Gráfico de Barras para Envío Promedio
plt.figure(figsize=(8, 6))
plt.bar(['Envío Promedio'], [envio_promedio2], color='green')
plt.title('Envío Promedio por Tienda 2')
plt.ylabel('Costo de Envío ($)')
plt.show()

print(" ")
print(f"Envío Promedio por Tienda numero 3: ${envio_promedio3:.2f}")

# Gráfico de Barras para Envío Promedio
plt.figure(figsize=(8, 6))
plt.bar(['Envío Promedio'], [envio_promedio3], color='red')
plt.title('Envío Promedio por Tienda 3')
plt.ylabel('Costo de Envío ($)')
plt.show()

print(" ")
print(f"Envío Promedio por tienda numero 4: ${envio_promedio4:.2f}")

# Gráfico de Barras para Envío Promedio
plt.figure(figsize=(8, 6))
plt.bar(['Envío Promedio'], [envio_promedio4], color='purple')
plt.title('Envío Promedio por Tienda 4')
plt.ylabel('Costo de Envío ($)')
plt.show()
# Out:
# Envío Promedio por tienda numero 1: $26018.61
#
# Envío Promedio por Tienda numero 2: $25216.24
#
# Envío Promedio por Tienda numero 3: $24805.68
#
# Envío Promedio por tienda numero 4: $23459.46

# %%
# Calcular el envío promedio
envio_promedio = tienda['Costo de envío'].mean()
envio_promedio2 = tienda2['Costo de envío'].mean()
envio_promedio3 = tienda3['Costo de envío'].mean()
envio_promedio4 = tienda4['Costo de envío'].mean()

categorias = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
calificacion_promedio_tiendas = [envio_promedio, envio_promedio2, envio_promedio3, envio_promedio4]
colores = ['blue', 'green', 'red', 'purple']
print(f"Envío Promedio por tienda numero 1: ${envio_promedio:.2f}")
print(f"Envío Promedio por tienda numero 2: ${envio_promedio2:.2f}")
print(f"Envío Promedio por tienda numero 3: ${envio_promedio3:.2f}")
print(f"Envío Promedio por tienda numero 4: ${envio_promedio4:.2f}")
print(" ")
# Crear figura y ejes
fig, ax = plt.subplots(figsize=(8, 5))

# Crear barras
barras = ax.bar(categorias, ventas, color=colores)

# Añadir título y etiquetas
ax.set_title("Envío Promedio por Tienda", fontsize=14)
ax.set_xlabel('Tiendas', fontsize=12)
ax.set_ylabel('Promedios', fontsize=12)

# Añadir valores encima de las barras
for barra in barras:
    height = barra.get_height()
    ax.text(barra.get_x() + barra.get_width()/2., height,
            f'{height}',
            ha='center', va='bottom')

# Mostrar gráfico
plt.tight_layout()
plt.show()
# Out:
# Envío Promedio por tienda numero 1: $26018.61
# Envío Promedio por tienda numero 2: $25216.24
# Envío Promedio por tienda numero 3: $24805.68
# Envío Promedio por tienda numero 4: $23459.46

# %% [markdown]
# ### Informe de Análisis y Recomendación de Venta de Tienda
#
# **Objetivo:**
#
# Determinar cuál de las cuatro tiendas analizadas en el notebook AluraStoreLatam.ipynb es la mejor candidata para la venta, considerando diferentes indicadores de rendimiento.
#
# **Metodología:**
#
# Se analizaron los siguientes indicadores clave de rendimiento para cada tienda, extraídos del notebook:
#
# Facturación Total: Representa el ingreso total generado por cada tienda.
# Ventas por Categoría: Permite identificar las categorías de productos más rentables en cada tienda.
# Calificación Promedio: Refleja la satisfacción general de los clientes con cada tienda.
# Productos Más y Menos Vendidos: Ayuda a comprender las preferencias de los clientes y la rotación de inventario.
# Envío Promedio: Indica el costo promedio de envío por tienda, lo que puede afectar la rentabilidad.
# Resultados:
#
# **Tienda 1**
#
# Facturacion total: $8029934.11 * Calificación promedio: 4.5732 * Envío promedio: $$8029934.11 * Calificación promedio: 4.5732 * Envío promedio: $15.12
# Productos más vendidos: Producto_19, Producto_13, Producto_18, Producto_1, Producto_17
# Productos menos vendidos: Producto_14, Producto_20, Producto_8, Producto_5, Producto_15
# Tienda 2
#
# Facturacion total: $7885171.03 * Calificación promedio: 4.5365 * Envío promedio: $$7885171.03 * Calificación promedio: 4.5365 * Envío promedio: $15.18
# Productos más vendidos: Producto_19, Producto_13, Producto_18, Producto_17, Producto_1
# Productos menos vendidos: Producto_20, Producto_14, Producto_8, Producto_5, Producto_15
# Tienda 3
#
# Facturacion total: $7711513.98 * Calificación promedio: 4.5732 * Envío promedio: $$7711513.98 * Calificación promedio: 4.5732 * Envío promedio: $15.25
# Productos más vendidos: Producto_19, Producto_13, Producto_18, Producto_1, Producto_17
# Productos menos vendidos: Producto_20, Producto_14, Producto_8, Producto_5, Producto_15
# Tienda 4
#
# Facturacion total: $7536989.91 * Calificación promedio: 4.5073 * Envío promedio: $$7536989.91 * Calificación promedio: 4.5073 * Envío promedio: $15.26
# Productos más vendidos: Producto_19, Producto_13, Producto_18, Producto_17, Producto_1
# Productos menos vendidos: Producto_20, Producto_14, Producto_8, Producto_5, Producto_15
# Recomendación:
#
# **Se recomienda vender la Tienda 4.**
#
# **Razonamiento**:
#
# Aunque la Tienda 4 tiene la facturación total más baja y el costo de envío promedio más alto, también tiene la calificación promedio más baja entre las cuatro tiendas. Esto podría indicar un menor potencial de crecimiento y una menor satisfacción del cliente en comparación con las otras tiendas. Al vender la Tienda 4, se podría obtener un retorno de inversión aceptable, mientras se mantienen las tiendas con mejor rendimiento y mayor potencial de crecimiento.
#
# **Consideraciones Adicionales:**
#
# Se debe realizar un análisis más profundo de la Tienda 4 para identificar las causas de su menor rendimiento y calificación.
# Se deben considerar factores externos, como la competencia y las tendencias del mercado, al tomar la decisión final.
# Espero que este informe te sea útil para tomar una decisión informada sobre la venta de la tienda.
#
# Recuerda: Este análisis se basa únicamente en los datos proporcionados en el notebook AluraStoreLatam.ipynb. Es importante considerar otros factores relevantes antes de tomar una decisión final.
